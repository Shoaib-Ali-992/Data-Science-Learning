# %%
import numpy as np

# %% [markdown]
# ### `Q-1:` Create a random 3x4 matrix with value between 0-100. And perform below tasks
#
#     i. Sort this matrix. np.sort()
#     ii. Sort this matrix based on values in 2nd column.
#     iii. Sort this matrix based on max value in each row.
#     iv. Sort based on elements value.

# %%
a = np.random.randint(0,100,(3,4))

# %%
a
# Out:
# array([[ 8, 24, 27, 24],
#        [14, 26,  9, 63],
#        [58, 93, 41, 73]], dtype=int32)

# %%
# rows wise sort
np.sort(a)
# Out:
# array([[ 8, 24, 24, 27],
#        [ 9, 14, 26, 63],
#        [41, 58, 73, 93]], dtype=int32)

# %%
# columns wise sort
np.sort(a,axis=0)
# Out:
# array([[ 8, 24,  9, 24],
#        [14, 26, 27, 63],
#        [58, 93, 41, 73]], dtype=int32)

# %%
# reverse sort rows wise
np.sort(a)[::-1]
# Out:
# array([[41, 58, 73, 93],
#        [ 9, 14, 26, 63],
#        [ 8, 24, 24, 27]], dtype=int32)

# %%
# colums wise reverse sort
np.sort(a,axis=0)[::-1]
# Out:
# array([[58, 93, 41, 73],
#        [14, 26, 27, 63],
#        [ 8, 24,  9, 24]], dtype=int32)

# %%
a
# Out:
# array([[ 8, 24, 27, 24],
#        [14, 26,  9, 63],
#        [58, 93, 41, 73]], dtype=int32)

# %%
b = np.array([[ 8, 24, 24, 27],
       [ 9, 14, 26, 63],
       [41, 58, 73, 93]])
b
# Out:
# array([[ 8, 24, 24, 27],
#        [ 9, 14, 26, 63],
#        [41, 58, 73, 93]])

# %%
print(np.sort(b[:,1],axis=0))
# Out:
# [14 24 58]

# %%
print(b[b[:, 1].argsort()])
# Out:
# [[ 9 14 26 63]
#  [ 8 24 24 27]
#  [41 58 73 93]]

# %%
b[:, 1].argsort()
# Out:
# array([1, 0, 2])

# %%
b[:,1]
# Out:
# array([24, 14, 58])

# %%
print(b[b[:, 1].argsort()])
# Out:
# [[ 9 14 26 63]
#  [ 8 24 24 27]
#  [41 58 73 93]]
